# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#import csv file
salary_data = pd.read_csv('Data Files/Clean_Payroll.csv')
salary_data.head()
# Out:
#    Unnamed: 0   Tm  Attendance  Attend/G  Est. Payroll  Year
# 0           0  ARI     2091685     25823      59984226  2006
# 1           1  ATL     2550524     31488      90156876  2006
# 2           2  BAL     2153139     26582      72585582  2006
# 3           3  BOS     2930588     36180     120099824  2006
# 4           4  CHC     3123215     38558      94424499  2006

# %%
#define x and y points
Attendance = salary_data['Attend/G']
Payroll = salary_data['Est. Payroll']

# %%
#create line plot for attendance vs. payroll
(slope, intercept, _, _, _) = linregress(Attendance, Payroll)
fit = slope * Attendance + intercept

fig, ax = plt.subplots()

fig.suptitle("Attendance vs. Total Payroll", fontsize=16)

ax.set_xlabel("Attendance per year")
ax.set_ylabel("Total Payroll")

ax.plot(Attendance, Payroll, linewidth=0, marker='o')

ax.plot(Attendance, fit, 'b')

plt.show()

# %%
grouped_salary_data= salary_data.groupby(['Tm'])
grouped_salary_data.mean()
# Out:
#      Unnamed: 0    Attendance      Attend/G  Est. Payroll    Year
# Tm
# ARI  150.000000  2.156396e+06  26622.181818  6.820516e+07  2011.0
# ATL  151.000000  2.402792e+06  29664.181818  9.333008e+07  2011.0
# BAL  152.000000  2.094682e+06  25986.090909  9.339868e+07  2011.0
# BOS  153.000000  2.980117e+06  36791.545455  1.523773e+08  2011.0
# CHC  154.000000  3.023161e+06  37367.454545  1.131352e+08  2011.0
# CHW  155.000000  2.137219e+06  26351.272727  1.074607e+08  2011.0
# CIN  156.000000  2.173045e+06  26862.545455  8.299061e+07  2011.0
# CLE  157.000000  1.730625e+06  21417.090909  7.145165e+07  2011.0
# COL  158.000000  2.617715e+06  32285.000000  7.784608e+07  2011.0
# DET  159.000000  2.796792e+06  34563.363636  1.358297e+08  2011.0
# HOU  160.545455  2.292172e+06  28337.545455  7.514050e+07  2011.0
# KCR  161.545455  1.856314e+06  22917.454545  7.692419e+07  2011.0
# LAA  162.545455  3.179346e+06  39251.181818  1.228294e+08  2011.0
# ...

# %%
ARI_salary_data = salary_data.loc[salary_data["Tm"] == "ARI", :]

# %%
x = ARI_salary_data['Year']
y = ARI_salary_data['Est. Payroll']
z = ARI_salary_data['Attendance']

ax = plt.subplot(111)
ax.bar(x, y, width=0.5, color='b', align='center')
ax.bar(x, z, width=0.5, color='g', align='center')

plt.show()

# %%
plt.pie(z,labels = x)
plt.show()

# %%
Attendance_Avg = grouped_salary_data['Attend/G']
Payroll_Avg = grouped_salary_data['Est. Payroll']

(slope, intercept, _, _, _) = linregress(Attendance_Avg, Payroll_Avg)
fit = slope * Attendance_Avg + intercept

fig, ax = plt.subplots()

fig.suptitle("Avg Attendance vs. Total Payroll per Team", fontsize=16)

ax.set_xlabel("Attendance per year")
ax.set_ylabel("Total Payroll")

ax.plot(Attendance_Avg, Payroll_Avg, linewidth=0, marker='o')

ax.plot(Attendance, fit, 'b')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...
