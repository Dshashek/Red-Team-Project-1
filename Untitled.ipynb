# %%
import pandas as pd

# %%
06_attendance = pd.read_csv("./2006.csv")
# Out:
#   File "<ipython-input-12-0b5f99cfd08a>", line 1
#     06_attendance = pd.read_csv("./2006.csv")
#       ^
# SyntaxError: invalid token

# %%
d2006
# Out:
#      Tm  Attendance  Attend/G  BatAge  PAge  BPF  PPF  #HOF  #A-S  #a-tA-S  \
# 0   ARI     2091685     25823    29.7  28.8  105  105     0     1       14
# 1   ATL     2550524     31488    27.5  29.4  100   99     2     3       12
# 2   BAL     2153139     26582    30.4  27.9   99   99     0     1        9
# 3   BOS     2930588     36180    30.5  31.1  105  104     0     4       18
# 4   CHC     3123215     38558    28.6  28.0  103  103     1     1       13
# 5   CHW     2957414     36511    29.8  27.9  104  104     1     7       16
# 6   CIN     2134607     26353    29.6  29.5  104  104     1     1       13
# 7   CLE     1997995     24667    27.7  28.6   99   98     0     1       14
# 8   COL     2104362     25980    27.8  28.8  109  109     0     2       10
# 9   DET     2595937     32049    29.3  28.8  100   99     1     3       15
# 10  FLA     1164134     14372    25.5  25.9   95   96     0     2        6
# ...
